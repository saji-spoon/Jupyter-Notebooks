# %% [markdown]
# # 独自データの分類 - サンプルモデルでの試行

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions
from chainer.dataset import concat_examples
import inspect
from jupyterthemes import jtplot
jtplot.style()
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import pyplot as plt
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

def generate_cmap(colors):
    """自分で定義したカラーマップを返す"""
    values = range(len(colors))

    vmax = np.ceil(np.max(values))
    color_list = []
    for v, c in zip(values, colors):
        color_list.append( ( v/ vmax, c) )
    return LinearSegmentedColormap.from_list('custom_cmap', color_list)

train, test = datasets.get_mnist()
train_iter = iterators.SerialIterator(train, batch_size=100, shuffle=True)
test_iter = iterators.SerialIterator(train, batch_size=100, shuffle=False, repeat=False)

# %% [markdown]
# ## データ用意

# %%
file = open("sample.txt", mode='r')
lines = file.readlines()

train_pos = []
t_label = []

for line in lines:
    vals = line.split(",")
    train_pos.append([int(vals[0]),480-int(vals[1])])
    t_label.append(int(vals[2]))

#train_array
#t_array

#デフォルトでtrain_posは座標そのままなので正規化する
sample_train = np.array(train_pos, np.float32) / np.array([640, 480], np.float32)
sample_train_t = np.array(t_label, np.int32)

import random
#暫定的に何個かサンプリングしてテスト用データとする
test_pos = []
test_t_label = []
for i in range(10) :
    idx = random.randrange(0, sample_train.shape[0])
    test_pos.append(train_pos[idx])
    test_t_label.append(t_label[idx])
    
sample_test = np.array(test_pos, np.float32) / np.array([640, 480], np.float32)
sample_test_t = np.array(test_t_label, np.int32)

#学習用データの表示
cm = generate_cmap(['#EE5050', '#9090FF'])
plt.scatter(sample_train[:,0], sample_train[:,1], c=sample_train_t, cmap=cm)

#テストデータの表示
cm_test = generate_cmap(['#50EE50', '#EE50EE'])
plt.scatter(sample_test[:,0], sample_test[:,1], c=sample_test_t, cmap=cm_test)

#格子点サンプルの用意
xx, yy = np.meshgrid(np.arange(0,1.0,0.05), np.arange(0,1.0,0.05))
sample_mesh = np.array(np.c_[xx.ravel(), yy.ravel()], np.float32)

from chainer.datasets import tuple_dataset

#最後に、iterで取り出しやすいようTupleDatasetの形にする
train = tuple_dataset.TupleDataset(sample_train, sample_train_t)
test = tuple_dataset.TupleDataset(sample_test, sample_test_t)

# %% [markdown]
# ### モデルの定義
#
# 今回は公式のMNISTチュートリアルで使ったのと同じモデルを用いる

# %%
class MLP(Chain):
    def __init__(self, n_units, n_out):
        super(MLP, self).__init__()
        with self.init_scope():
            self.l1 = L.Linear(None, n_units)
            self.l2 = L.Linear(None, n_units)
            self.l3 = L.Linear(None, n_out)
            
            
    def __call__(self, x):
        #層の結合結果に、活性化関数をかませる
        h1 = F.relu(self.l1(x))
        h2 = F.relu(self.l2(h1))
        y = self.l3(h2)
        return y
    
class Classifier(Chain):
    def __init__(self, predictor):
        super(Classifier, self).__init__()
        with self.init_scope():
            self.predictor = predictor
            
    def __call__(self, x, t):
        y = self.predictor(x)
        loss = F.softmax_cross_entropy(y, t)
        accuracy = F.accuracy(y, t)
        report({'loss':loss, 'accuracy':accuracy})        
        return loss

# %% [markdown]
# ## ビギナー向けチュートリアルに沿った実装
#
# https://qiita.com/mitmul/items/eccf4e0a84cb784ba84a
#
# 2 Iteratorぐらいから
#
# サンプルに対してiteratorを定義する

# %%
len(train)

train_batchsize = 1

train_iter = iterators.SerialIterator(train, train_batchsize)
test_iter = iterators.SerialIterator(test, 10, repeat=False, shuffle=False)
# Out:
# 217

# %% [markdown]
# optimizerを定義し、モデルをセットする

# %%
#ここで学習率の設定
optimizer = optimizers.SGD(lr = 0.01)
#上で定義したモデルのインスタンス作成　中間ノード数100, 最終出力2
model = MLP(100, 2)
optimizer.setup(model)

# %% [markdown]
# ### 学習ループ
#
# 1. 入力をmodelで計算して出力yを得る
# 2. yからloss値を計算する　今回はsoftmax_cross_entropyを使う
# 3. loss値に対する各パラメータの勾配を計算する
# 4. optimizerでupdate

# %%
max_epoch = 200

while train_iter.epoch < max_epoch:
    #バッチを1つ取り出す
    train_batch = train_iter.next()
    #学習用データとラベルを一緒にとってしまっているのでバラす
    x, t = concat_examples(train_batch)
    #出力を得る
    y = model(x)
    #lossを計算
    loss = F.softmax_cross_entropy(y, t)    
    #新しく勾配計算を始めるごとに初期化
    model.cleargrads()
    #lossに対して各パラメータの勾配を計算
    loss.backward()
    #勾配計算済みなので引数なしでupdateを呼び出す
    optimizer.update() 
    
    #テストデータに対してモデルを適用し,accuracyとlossを算出
    #モデルの性能が上がっていることを確かめる
    test_losses = []
    test_accuracies = []
    if train_iter.is_new_epoch:
        while True:
            test_batch = test_iter.next()
            x, t = concat_examples(test_batch)
            y = model(x)
            loss = F.softmax_cross_entropy(y, t)    
            accuracy = F.accuracy(y, t)
            print("Now at ", train_iter.epoch)
            print("loss:", loss)
            print("accuracy:", accuracy)
            
            if test_iter.is_new_epoch:
                test_iter.reset()
                break
# Out:
# Now at  1
# loss: variable(0.5261179804801941)
# accuracy: variable(0.699999988079071)
# Now at  2
# loss: variable(0.47368890047073364)
# accuracy: variable(0.699999988079071)
# Now at  3
# loss: variable(0.45868778228759766)
# accuracy: variable(0.699999988079071)
# Now at  4
# loss: variable(0.3830416202545166)
# accuracy: variable(0.800000011920929)
# Now at  5
# loss: variable(0.42413029074668884)
# accuracy: variable(0.800000011920929)
# Now at  6
# loss: variable(0.7479631304740906)
# accuracy: variable(0.699999988079071)
# Now at  7
# loss: variable(0.5681716203689575)
# accuracy: variable(0.699999988079071)
# Now at  8
# loss: variable(0.23837676644325256)
# accuracy: variable(0.8999999761581421)
# Now at  9
# loss: variable(0.4211539328098297)
# accuracy: variable(0.800000011920929)
# Now at  10
# loss: variable(0.5731451511383057)
# accuracy: variable(0.699999988079071)
# Now at  11
# loss: variable(0.46365830302238464)
# accuracy: variable(0.800000011920929)
# Now at  12
# loss: variable(0.2614431381225586)
# accuracy: variable(0.8999999761581421)
# Now at  13
# loss: variable(0.3059554696083069)
# accuracy: variable(0.8999999761581421)
# Now at  14
# loss: variable(0.4263781011104584)
# accuracy: variable(0.800000011920929)
# Now at  15
# loss: variable(0.30345433950424194)
# accuracy: variable(0.8999999761581421)
# Now at  16
# loss: variable(0.3248772621154785)
# accuracy: variable(0.800000011920929)
# Now at  17
# loss: variable(0.2880973815917969)
# accuracy: variable(0.8999999761581421)
# Now at  18
# loss: variable(0.46526336669921875)
# accuracy: variable(0.8999999761581421)
# Now at  19
# loss: variable(0.33240991830825806)
# accuracy: variable(0.8999999761581421)
# Now at  20
# loss: variable(0.42793866991996765)
# accuracy: variable(0.800000011920929)
# Now at  21
# loss: variable(0.4379524886608124)
# accuracy: variable(0.800000011920929)
# Now at  22
# loss: variable(0.5470341444015503)
# accuracy: variable(0.800000011920929)
# Now at  23
# loss: variable(0.25471749901771545)
# accuracy: variable(0.8999999761581421)
# Now at  24
# loss: variable(0.4476216435432434)
# accuracy: variable(0.800000011920929)
# Now at  25
# loss: variable(0.2583003640174866)
# accuracy: variable(0.8999999761581421)
# Now at  26
# loss: variable(0.28991690278053284)
# accuracy: variable(0.800000011920929)
# Now at  27
# loss: variable(0.33732208609580994)
# accuracy: variable(0.8999999761581421)
# Now at  28
# loss: variable(0.2647702693939209)
# accuracy: variable(0.8999999761581421)
# Now at  29
# loss: variable(0.31296446919441223)
# accuracy: variable(0.800000011920929)
# Now at  30
# loss: variable(0.2824915945529938)
# accuracy: variable(0.800000011920929)
# Now at  31
# loss: variable(0.32320094108581543)
# accuracy: variable(0.8999999761581421)
# Now at  32
# loss: variable(0.4071836471557617)
# accuracy: variable(0.800000011920929)
# Now at  33
# loss: variable(0.23936830461025238)
# accuracy: variable(0.8999999761581421)
# Now at  34
# loss: variable(0.6179457902908325)
# accuracy: variable(0.800000011920929)
# Now at  35
# loss: variable(0.18271762132644653)
# accuracy: variable(0.8999999761581421)
# Now at  36
# loss: variable(0.2315727025270462)
# accuracy: variable(0.8999999761581421)
# Now at  37
# loss: variable(0.13373641669750214)
# accuracy: variable(0.8999999761581421)
# Now at  38
# loss: variable(0.13636215031147003)
# accuracy: variable(0.8999999761581421)
# Now at  39
# loss: variable(0.1686067283153534)
# accuracy: variable(0.8999999761581421)
# Now at  40
# loss: variable(0.33692818880081177)
# accuracy: variable(0.8999999761581421)
# Now at  41
# loss: variable(0.16475006937980652)
# accuracy: variable(0.8999999761581421)
# Now at  42
# loss: variable(0.11965718120336533)
# accuracy: variable(1.0)
# Now at  43
# loss: variable(0.15088282525539398)
# accuracy: variable(0.8999999761581421)
# Now at  44
# loss: variable(0.10989953577518463)
# accuracy: variable(1.0)
# Now at  45
# loss: variable(0.20200276374816895)
# accuracy: variable(0.800000011920929)
# Now at  46
# loss: variable(0.3423953950405121)
# accuracy: variable(0.8999999761581421)
# Now at  47
# loss: variable(0.30150696635246277)
# accuracy: variable(0.800000011920929)
# Now at  48
# loss: variable(0.10999128967523575)
# accuracy: variable(1.0)
# Now at  49
# loss: variable(0.11160805076360703)
# accuracy: variable(1.0)
# Now at  50
# loss: variable(0.13657449185848236)
# accuracy: variable(0.8999999761581421)
# Now at  51
# loss: variable(0.13982132077217102)
# accuracy: variable(0.8999999761581421)
# Now at  52
# loss: variable(0.10222659260034561)
# accuracy: variable(1.0)
# Now at  53
# loss: variable(0.21926000714302063)
# accuracy: variable(0.8999999761581421)
# Now at  54
# loss: variable(0.1992492973804474)
# accuracy: variable(0.8999999761581421)
# Now at  55
# loss: variable(0.12471895664930344)
# accuracy: variable(0.8999999761581421)
# Now at  56
# loss: variable(0.14531052112579346)
# accuracy: variable(0.8999999761581421)
# Now at  57
# loss: variable(0.16678625345230103)
# accuracy: variable(0.8999999761581421)
# Now at  58
# loss: variable(0.20424337685108185)
# accuracy: variable(0.8999999761581421)
# Now at  59
# loss: variable(0.14133921265602112)
# accuracy: variable(0.8999999761581421)
# Now at  60
# loss: variable(0.24724368751049042)
# accuracy: variable(0.8999999761581421)
# Now at  61
# loss: variable(0.18595412373542786)
# accuracy: variable(0.8999999761581421)
# Now at  62
# loss: variable(0.2538813054561615)
# accuracy: variable(0.8999999761581421)
# Now at  63
# loss: variable(0.35122811794281006)
# accuracy: variable(0.800000011920929)
# Now at  64
# loss: variable(0.5062392950057983)
# accuracy: variable(0.8999999761581421)
# Now at  65
# loss: variable(0.10323747247457504)
# accuracy: variable(1.0)
# Now at  66
# loss: variable(0.25232043862342834)
# accuracy: variable(0.800000011920929)
# Now at  67
# loss: variable(0.3795780837535858)
# accuracy: variable(0.8999999761581421)
# Now at  68
# loss: variable(0.42847806215286255)
# accuracy: variable(0.8999999761581421)
# Now at  69
# loss: variable(0.1023368388414383)
# accuracy: variable(1.0)
# Now at  70
# loss: variable(0.10271813720464706)
# accuracy: variable(1.0)
# Now at  71
# loss: variable(0.08947168290615082)
# accuracy: variable(1.0)
# Now at  72
# loss: variable(0.209542378783226)
# accuracy: variable(0.8999999761581421)
# Now at  73
# loss: variable(0.10248768329620361)
# accuracy: variable(1.0)
# Now at  74
# loss: variable(0.3112984597682953)
# accuracy: variable(0.8999999761581421)
# Now at  75
# loss: variable(0.10634181648492813)
# accuracy: variable(1.0)
# Now at  76
# loss: variable(0.27736902236938477)
# accuracy: variable(0.8999999761581421)
# Now at  77
# loss: variable(0.564727783203125)
# accuracy: variable(0.8999999761581421)
# Now at  78
# loss: variable(0.20727470517158508)
# accuracy: variable(0.8999999761581421)
# Now at  79
# loss: variable(0.20381319522857666)
# accuracy: variable(0.8999999761581421)
# Now at  80
# loss: variable(0.12796473503112793)
# accuracy: variable(0.8999999761581421)
# Now at  81
# loss: variable(0.09996851533651352)
# accuracy: variable(1.0)
# Now at  82
# loss: variable(0.3129008412361145)
# accuracy: variable(0.8999999761581421)
# Now at  83
# loss: variable(0.15927958488464355)
# accuracy: variable(0.8999999761581421)
# Now at  84
# loss: variable(0.13820138573646545)
# accuracy: variable(0.8999999761581421)
# Now at  85
# loss: variable(0.08979402482509613)
# accuracy: variable(1.0)
# Now at  86
# loss: variable(0.1226072832942009)
# accuracy: variable(1.0)
# Now at  87
# loss: variable(0.13251246511936188)
# accuracy: variable(1.0)
# Now at  88
# loss: variable(0.1287088841199875)
# accuracy: variable(1.0)
# Now at  89
# loss: variable(0.1284804344177246)
# accuracy: variable(1.0)
# Now at  90
# loss: variable(0.08602189272642136)
# accuracy: variable(1.0)
# Now at  91
# loss: variable(0.12457010895013809)
# accuracy: variable(0.8999999761581421)
# Now at  92
# loss: variable(0.17347906529903412)
# accuracy: variable(0.8999999761581421)
# Now at  93
# loss: variable(0.15891291201114655)
# accuracy: variable(0.8999999761581421)
# Now at  94
# loss: variable(0.19266848266124725)
# accuracy: variable(0.8999999761581421)
# Now at  95
# loss: variable(0.11002041399478912)
# accuracy: variable(1.0)
# Now at  96
# loss: variable(0.12534379959106445)
# accuracy: variable(0.8999999761581421)
# Now at  97
# loss: variable(0.18932853639125824)
# accuracy: variable(0.8999999761581421)
# Now at  98
# loss: variable(0.12784947454929352)
# accuracy: variable(0.8999999761581421)
# Now at  99
# loss: variable(0.31976714730262756)
# accuracy: variable(0.8999999761581421)
# Now at  100
# loss: variable(0.0979715883731842)
# accuracy: variable(1.0)
# Now at  101
# loss: variable(0.08942138403654099)
# accuracy: variable(1.0)
# Now at  102
# loss: variable(0.26897865533828735)
# accuracy: variable(0.8999999761581421)
# Now at  103
# loss: variable(0.13853363692760468)
# accuracy: variable(0.8999999761581421)
# Now at  104
# loss: variable(0.08988223969936371)
# accuracy: variable(1.0)
# Now at  105
# loss: variable(0.09729523956775665)
# accuracy: variable(1.0)
# Now at  106
# loss: variable(0.10476069897413254)
# accuracy: variable(0.8999999761581421)
# Now at  107
# loss: variable(0.08585947751998901)
# accuracy: variable(1.0)
# Now at  108
# loss: variable(0.1459214687347412)
# accuracy: variable(0.8999999761581421)
# Now at  109
# loss: variable(0.13907675445079803)
# accuracy: variable(1.0)
# Now at  110
# loss: variable(0.2434028685092926)
# accuracy: variable(0.8999999761581421)
# Now at  111
# loss: variable(0.13777653872966766)
# accuracy: variable(0.8999999761581421)
# Now at  112
# loss: variable(0.09668153524398804)
# accuracy: variable(1.0)
# Now at  113
# loss: variable(0.08268921077251434)
# accuracy: variable(1.0)
# Now at  114
# loss: variable(0.09583642333745956)
# accuracy: variable(1.0)
# Now at  115
# loss: variable(0.10568900406360626)
# accuracy: variable(0.8999999761581421)
# Now at  116
# loss: variable(0.15092162787914276)
# accuracy: variable(0.8999999761581421)
# Now at  117
# loss: variable(0.09707006067037582)
# accuracy: variable(1.0)
# Now at  118
# loss: variable(0.0916147455573082)
# accuracy: variable(1.0)
# Now at  119
# loss: variable(0.18817634880542755)
# accuracy: variable(0.8999999761581421)
# Now at  120
# loss: variable(0.08365663141012192)
# accuracy: variable(1.0)
# Now at  121
# loss: variable(0.18412336707115173)
# accuracy: variable(0.8999999761581421)
# Now at  122
# loss: variable(0.4294677674770355)
# accuracy: variable(0.8999999761581421)
# Now at  123
# loss: variable(0.09984196722507477)
# accuracy: variable(0.8999999761581421)
# Now at  124
# loss: variable(0.18745671212673187)
# accuracy: variable(0.8999999761581421)
# Now at  125
# loss: variable(0.10065054893493652)
# accuracy: variable(0.8999999761581421)
# Now at  126
# loss: variable(0.1333351582288742)
# accuracy: variable(1.0)
# Now at  127
# loss: variable(0.08631335943937302)
# accuracy: variable(1.0)
# Now at  128
# loss: variable(0.08967731148004532)
# accuracy: variable(1.0)
# Now at  129
# loss: variable(0.09391500800848007)
# accuracy: variable(1.0)
# Now at  130
# loss: variable(0.11112622171640396)
# accuracy: variable(0.8999999761581421)
# Now at  131
# loss: variable(0.15057742595672607)
# accuracy: variable(0.8999999761581421)
# Now at  132
# loss: variable(0.1644531637430191)
# accuracy: variable(0.8999999761581421)
# Now at  133
# loss: variable(0.12449359893798828)
# accuracy: variable(0.8999999761581421)
# Now at  134
# loss: variable(0.21264640986919403)
# accuracy: variable(0.8999999761581421)
# Now at  135
# loss: variable(0.08029687404632568)
# accuracy: variable(1.0)
# Now at  136
# loss: variable(0.11889772862195969)
# accuracy: variable(0.8999999761581421)
# Now at  137
# loss: variable(0.1372678279876709)
# accuracy: variable(0.8999999761581421)
# Now at  138
# loss: variable(0.09321042150259018)
# accuracy: variable(1.0)
# Now at  139
# loss: variable(0.08835174888372421)
# accuracy: variable(1.0)
# Now at  140
# loss: variable(0.12257591634988785)
# accuracy: variable(0.8999999761581421)
# Now at  141
# loss: variable(0.15863102674484253)
# accuracy: variable(0.8999999761581421)
# Now at  142
# loss: variable(0.09710093587636948)
# accuracy: variable(0.8999999761581421)
# Now at  143
# loss: variable(0.08216410875320435)
# accuracy: variable(1.0)
# Now at  144
# loss: variable(0.43766433000564575)
# accuracy: variable(0.8999999761581421)
# Now at  145
# loss: variable(0.10577541589736938)
# accuracy: variable(0.8999999761581421)
# Now at  146
# loss: variable(0.0999528244137764)
# accuracy: variable(0.8999999761581421)
# Now at  147
# loss: variable(0.10945480316877365)
# accuracy: variable(0.8999999761581421)
# Now at  148
# loss: variable(0.08540553599596024)
# accuracy: variable(1.0)
# Now at  149
# loss: variable(0.10147863626480103)
# accuracy: variable(1.0)
# Now at  150
# loss: variable(0.09823918342590332)
# accuracy: variable(0.8999999761581421)
# Now at  151
# loss: variable(0.20920267701148987)
# accuracy: variable(0.8999999761581421)
# Now at  152
# loss: variable(0.13690628111362457)
# accuracy: variable(0.8999999761581421)
# Now at  153
# loss: variable(0.08090635389089584)
# accuracy: variable(1.0)
# Now at  154
# loss: variable(0.07599369436502457)
# accuracy: variable(1.0)
# Now at  155
# loss: variable(0.14811258018016815)
# accuracy: variable(0.8999999761581421)
# Now at  156
# loss: variable(0.09940807521343231)
# accuracy: variable(1.0)
# Now at  157
# loss: variable(0.09876364469528198)
# accuracy: variable(0.8999999761581421)
# Now at  158
# loss: variable(0.1455928385257721)
# accuracy: variable(0.8999999761581421)
# Now at  159
# loss: variable(0.07579045742750168)
# accuracy: variable(1.0)
# Now at  160
# loss: variable(0.0936562791466713)
# accuracy: variable(1.0)
# Now at  161
# loss: variable(0.12726615369319916)
# accuracy: variable(0.8999999761581421)
# Now at  162
# loss: variable(0.09916508197784424)
# accuracy: variable(1.0)
# Now at  163
# loss: variable(0.4183531403541565)
# accuracy: variable(0.8999999761581421)
# Now at  164
# loss: variable(0.15343554317951202)
# accuracy: variable(0.8999999761581421)
# Now at  165
# loss: variable(0.09499428421258926)
# accuracy: variable(0.8999999761581421)
# Now at  166
# loss: variable(0.07615764439105988)
# accuracy: variable(1.0)
# Now at  167
# loss: variable(0.24706673622131348)
# accuracy: variable(0.8999999761581421)
# Now at  168
# loss: variable(0.09992661327123642)
# accuracy: variable(0.8999999761581421)
# Now at  169
# loss: variable(0.1081652045249939)
# accuracy: variable(0.8999999761581421)
# Now at  170
# loss: variable(0.10133848339319229)
# accuracy: variable(0.8999999761581421)
# Now at  171
# loss: variable(0.17296236753463745)
# accuracy: variable(0.8999999761581421)
# Now at  172
# loss: variable(0.10655021667480469)
# accuracy: variable(0.8999999761581421)
# Now at  173
# loss: variable(0.23911908268928528)
# accuracy: variable(0.8999999761581421)
# Now at  174
# loss: variable(0.08240347355604172)
# accuracy: variable(1.0)
# Now at  175
# loss: variable(0.10984188318252563)
# accuracy: variable(0.8999999761581421)
# Now at  176
# loss: variable(0.133992001414299)
# accuracy: variable(0.8999999761581421)
# Now at  177
# loss: variable(0.21845927834510803)
# accuracy: variable(0.8999999761581421)
# Now at  178
# loss: variable(0.07251754403114319)
# accuracy: variable(1.0)
# Now at  179
# loss: variable(0.10426081717014313)
# accuracy: variable(0.8999999761581421)
# Now at  180
# loss: variable(0.09454040974378586)
# accuracy: variable(1.0)
# Now at  181
# loss: variable(0.16757790744304657)
# accuracy: variable(0.8999999761581421)
# Now at  182
# loss: variable(0.518162727355957)
# accuracy: variable(0.8999999761581421)
# Now at  183
# loss: variable(0.07849064469337463)
# accuracy: variable(1.0)
# Now at  184
# loss: variable(0.09102912247180939)
# accuracy: variable(1.0)
# Now at  185
# loss: variable(0.07925116270780563)
# accuracy: variable(1.0)
# Now at  186
# loss: variable(0.08604563027620316)
# accuracy: variable(1.0)
# Now at  187
# loss: variable(0.09016582369804382)
# accuracy: variable(1.0)
# Now at  188
# loss: variable(0.08703817427158356)
# accuracy: variable(1.0)
# Now at  189
# loss: variable(0.07503990828990936)
# accuracy: variable(1.0)
# Now at  190
# loss: variable(0.07465436309576035)
# accuracy: variable(1.0)
# Now at  191
# loss: variable(0.09703506529331207)
# accuracy: variable(0.8999999761581421)
# Now at  192
# loss: variable(0.09326338022947311)
# accuracy: variable(0.8999999761581421)
# Now at  193
# loss: variable(0.11511114984750748)
# accuracy: variable(1.0)
# Now at  194
# loss: variable(0.11053305119276047)
# accuracy: variable(0.8999999761581421)
# Now at  195
# loss: variable(0.16147616505622864)
# accuracy: variable(0.8999999761581421)
# Now at  196
# loss: variable(0.14515165984630585)
# accuracy: variable(0.8999999761581421)
# Now at  197
# loss: variable(0.15074923634529114)
# accuracy: variable(0.8999999761581421)
# Now at  198
# loss: variable(0.224299356341362)
# accuracy: variable(0.8999999761581421)
# Now at  199
# loss: variable(0.23371215164661407)
# accuracy: variable(0.8999999761581421)
# Now at  200
# loss: variable(0.13095855712890625)
# accuracy: variable(0.8999999761581421)

# %% [markdown]
# ### 作成モデルを格子点に適用して可視化
#
# 作成したデータ点-クラスラベルを学習したモデルを用いて
#
# 各格子点をどのようにクラス分けするか見る
#
# これによって分類境界を見ることができる

# %%
y = model(sample_mesh)

predict_label = F.argmax(y, axis=1).data
type(predict_label)

cm = generate_cmap(['#000000', '#FFFFFF'])
plt.scatter(sample_mesh[:,0], sample_mesh[:,1], c=predict_label, cmap=cm)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 知見など
#
# 今回の用にサンプル数が少ないと、バッチサイズを大きくしすぎるとコーナーケースのlossが潰れる？（図右端のクラス1（青）など）
#
# やはり学習率は重要っぽい
#
# 他中間ノード数などで調節可能
