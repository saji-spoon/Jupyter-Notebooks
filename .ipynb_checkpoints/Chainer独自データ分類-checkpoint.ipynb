# %% [markdown]
# # 独自データの分類 - 改良版

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions
from chainer.dataset import concat_examples
import inspect
from jupyterthemes import jtplot
jtplot.style()
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import pyplot as plt
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

def generate_cmap(colors):
    """自分で定義したカラーマップを返す"""
    values = range(len(colors))

    vmax = np.ceil(np.max(values))
    color_list = []
    for v, c in zip(values, colors):
        color_list.append( ( v/ vmax, c) )
    return LinearSegmentedColormap.from_list('custom_cmap', color_list)

train, test = datasets.get_mnist()
train_iter = iterators.SerialIterator(train, batch_size=100, shuffle=True)
test_iter = iterators.SerialIterator(train, batch_size=100, shuffle=False, repeat=False)

# %% [markdown]
# ## データ用意

# %%
file = open("sample1.txt", mode='r')
lines = file.readlines()

file.close()

train_pos = []
t_label = []

for line in lines:
    vals = line.split(",")
    train_pos.append([int(vals[0]),480-int(vals[1])])
    t_label.append(int(vals[2]))

#train_array
#t_array

#デフォルトでtrain_posは座標そのままなので正規化する
sample_train = np.array(train_pos, np.float32) / np.array([640, 480], np.float32)
sample_train_t = np.array(t_label, np.int32)

import random
#暫定的に何個かサンプリングしてテスト用データとする
test_pos = []
test_t_label = []
for i in range(20) :
    idx = random.randrange(0, sample_train.shape[0])
    test_pos.append(train_pos[idx])
    test_t_label.append(t_label[idx])
    
sample_test = np.array(test_pos, np.float32) / np.array([640, 480], np.float32)
sample_test_t = np.array(test_t_label, np.int32)

#学習用データの表示
cm = generate_cmap(['#EE5050', '#9090FF'])
plt.scatter(sample_train[:,0], sample_train[:,1], c=sample_train_t, cmap=cm)

#コメントアウトを外してテストデータの表示
cm_test = generate_cmap(['#50EE50', '#EE50EE'])
#plt.scatter(sample_test[:,0], sample_test[:,1], c=sample_test_t, cmap=cm_test)

#格子点サンプルの用意
xx, yy = np.meshgrid(np.arange(0,1.0,0.01), np.arange(0,1.0,0.01))
sample_mesh = np.array(np.c_[xx.ravel(), yy.ravel()], np.float32)

from chainer.datasets import tuple_dataset

#最後に、iterで取り出しやすいようTupleDatasetの形にする
train = tuple_dataset.TupleDataset(sample_train, sample_train_t)
test = tuple_dataset.TupleDataset(sample_test, sample_test_t)

# %% [markdown]
# ### モデルの定義

# %%
class MLP(Chain):
    def __init__(self, n_out):
        super(MLP, self).__init__()
        with self.init_scope():
            self.l1 = L.Linear(None, 100)
            self.l2 = L.Linear(None, 100)
            self.l3 = L.Linear(None, 100)
            self.l4 = L.Linear(None, 80)
            self.l5 = L.Linear(None, 50)
            self.l6 = L.Linear(None, 20)
            self.l7 = L.Linear(None, n_out)
            
            
    def __call__(self, x):
        #層の結合結果に、活性化関数をかませる
        h1 = F.tanh(self.l1(x))
        h2 = F.tanh(self.l2(h1))
        h3 = F.tanh(self.l3(h2))
        h4 = F.tanh(self.l4(h3))
        h5 = F.tanh(self.l5(h4))
        h6 = F.tanh(self.l6(h5))
        y = self.l7(h6)
        return y
    
class Classifier(Chain):
    def __init__(self, predictor):
        super(Classifier, self).__init__()
        with self.init_scope():
            self.predictor = predictor
            
    def __call__(self, x, t):
        y = self.predictor(x)
        loss = F.softmax_cross_entropy(y, t)
        accuracy = F.accuracy(y, t)
        report({'loss':loss, 'accuracy':accuracy})        
        return loss

# %% [markdown]
# ## ビギナー向けチュートリアルに沿った実装
#
# https://qiita.com/mitmul/items/eccf4e0a84cb784ba84a
#
# 2 Iteratorぐらいから
#
# サンプルに対してiteratorを定義する

# %%
len(train)

train_batchsize = 1

train_iter = iterators.SerialIterator(train, train_batchsize)
test_iter = iterators.SerialIterator(test, 20, repeat=False, shuffle=False)
# Out:
# 81

# %% [markdown]
# optimizerを定義し、モデルをセットする

# %%
#ここで学習率の設定
optimizer = optimizers.SGD(lr = 0.005)
#上で定義したモデルのインスタンス作成 最終出力2
model = MLP(2)
optimizer.setup(model)

# %% [markdown]
# ### 学習ループ
#
# 1. 入力をmodelで計算して出力yを得る
# 2. yからloss値を計算する　今回はsoftmax_cross_entropyを使う
# 3. loss値に対する各パラメータの勾配を計算する
# 4. optimizerでupdate

# %%
max_epoch = 200

while train_iter.epoch < max_epoch:
    #バッチを1つ取り出す
    train_batch = train_iter.next()
    #学習用データとラベルを一緒にとってしまっているのでバラす
    x, t = concat_examples(train_batch)
    #出力を得る
    y = model(x)
    #lossを計算
    loss = F.softmax_cross_entropy(y, t)    
    #新しく勾配計算を始めるごとに初期化
    model.cleargrads()
    #lossに対して各パラメータの勾配を計算
    loss.backward()
    #勾配計算済みなので引数なしでupdateを呼び出す
    optimizer.update() 
    
    #テストデータに対してモデルを適用し,accuracyとlossを算出
    #モデルの性能が上がっていることを確かめる
    test_losses = []
    test_accuracies = []
    if train_iter.is_new_epoch:
        while True:
            test_batch = test_iter.next()
            x, t = concat_examples(test_batch)
            y = model(x)
            loss = F.softmax_cross_entropy(y, t)    
            accuracy = F.accuracy(y, t)
            print("Now at ", train_iter.epoch)
            print("loss:", loss)
            print("accuracy:", accuracy)
            
            if test_iter.is_new_epoch:
                test_iter.reset()
                break
# Out:
# Now at  1
# loss: variable(0.8515657782554626)
# accuracy: variable(0.3499999940395355)
# Now at  2
# loss: variable(0.8094472289085388)
# accuracy: variable(0.3499999940395355)
# Now at  3
# loss: variable(0.8084650039672852)
# accuracy: variable(0.3499999940395355)
# Now at  4
# loss: variable(0.8442021608352661)
# accuracy: variable(0.3499999940395355)
# Now at  5
# loss: variable(0.6875645518302917)
# accuracy: variable(0.4000000059604645)
# Now at  6
# loss: variable(0.7956122756004333)
# accuracy: variable(0.3499999940395355)
# Now at  7
# loss: variable(0.6809521913528442)
# accuracy: variable(0.4000000059604645)
# Now at  8
# loss: variable(0.6137757897377014)
# accuracy: variable(0.6499999761581421)
# Now at  9
# loss: variable(0.5642164945602417)
# accuracy: variable(0.75)
# Now at  10
# loss: variable(0.4942398965358734)
# accuracy: variable(0.8500000238418579)
# Now at  11
# loss: variable(0.5354355573654175)
# accuracy: variable(0.75)
# Now at  12
# loss: variable(0.46698257327079773)
# accuracy: variable(0.800000011920929)
# Now at  13
# loss: variable(0.932884693145752)
# accuracy: variable(0.3499999940395355)
# Now at  14
# loss: variable(0.38759860396385193)
# accuracy: variable(0.8999999761581421)
# Now at  15
# loss: variable(0.4800773561000824)
# accuracy: variable(0.800000011920929)
# Now at  16
# loss: variable(0.6366197466850281)
# accuracy: variable(0.6499999761581421)
# Now at  17
# loss: variable(0.4326622486114502)
# accuracy: variable(0.800000011920929)
# Now at  18
# loss: variable(0.39888620376586914)
# accuracy: variable(0.8500000238418579)
# Now at  19
# loss: variable(0.34322795271873474)
# accuracy: variable(0.8999999761581421)
# Now at  20
# loss: variable(0.38809889554977417)
# accuracy: variable(0.8500000238418579)
# Now at  21
# loss: variable(0.48872676491737366)
# accuracy: variable(0.800000011920929)
# Now at  22
# loss: variable(0.41650018095970154)
# accuracy: variable(0.800000011920929)
# Now at  23
# loss: variable(0.6080304980278015)
# accuracy: variable(0.699999988079071)
# Now at  24
# loss: variable(0.31274476647377014)
# accuracy: variable(0.8999999761581421)
# Now at  25
# loss: variable(0.3418281674385071)
# accuracy: variable(0.8500000238418579)
# Now at  26
# loss: variable(0.45272156596183777)
# accuracy: variable(0.800000011920929)
# Now at  27
# loss: variable(0.7637545466423035)
# accuracy: variable(0.5)
# Now at  28
# loss: variable(0.33390212059020996)
# accuracy: variable(0.8999999761581421)
# Now at  29
# loss: variable(0.2848013639450073)
# accuracy: variable(0.8999999761581421)
# Now at  30
# loss: variable(0.46860209107398987)
# accuracy: variable(0.800000011920929)
# Now at  31
# loss: variable(0.3503487706184387)
# accuracy: variable(0.8500000238418579)
# Now at  32
# loss: variable(0.42581626772880554)
# accuracy: variable(0.800000011920929)
# Now at  33
# loss: variable(0.3178757131099701)
# accuracy: variable(0.8999999761581421)
# Now at  34
# loss: variable(0.41880449652671814)
# accuracy: variable(0.800000011920929)
# Now at  35
# loss: variable(0.3781387507915497)
# accuracy: variable(0.8999999761581421)
# Now at  36
# loss: variable(0.37195566296577454)
# accuracy: variable(0.8500000238418579)
# Now at  37
# loss: variable(0.28399500250816345)
# accuracy: variable(0.8999999761581421)
# Now at  38
# loss: variable(0.2963128983974457)
# accuracy: variable(0.8999999761581421)
# Now at  39
# loss: variable(0.3489627540111542)
# accuracy: variable(0.8999999761581421)
# Now at  40
# loss: variable(0.33160534501075745)
# accuracy: variable(0.8999999761581421)
# Now at  41
# loss: variable(0.27619481086730957)
# accuracy: variable(0.8999999761581421)
# Now at  42
# loss: variable(0.4443293511867523)
# accuracy: variable(0.800000011920929)
# Now at  43
# loss: variable(0.593384325504303)
# accuracy: variable(0.6000000238418579)
# Now at  44
# loss: variable(0.5636461973190308)
# accuracy: variable(0.6499999761581421)
# Now at  45
# loss: variable(0.3660448491573334)
# accuracy: variable(0.8999999761581421)
# Now at  46
# loss: variable(0.5731127262115479)
# accuracy: variable(0.6499999761581421)
# Now at  47
# loss: variable(0.3524097502231598)
# accuracy: variable(0.8999999761581421)
# Now at  48
# loss: variable(0.32334044575691223)
# accuracy: variable(0.8999999761581421)
# Now at  49
# loss: variable(0.38930168747901917)
# accuracy: variable(0.8999999761581421)
# Now at  50
# loss: variable(0.3833656907081604)
# accuracy: variable(0.8500000238418579)
# Now at  51
# loss: variable(0.2814541459083557)
# accuracy: variable(0.8999999761581421)
# Now at  52
# loss: variable(0.4719700813293457)
# accuracy: variable(0.800000011920929)
# Now at  53
# loss: variable(0.3944459557533264)
# accuracy: variable(0.8500000238418579)
# Now at  54
# loss: variable(0.22702430188655853)
# accuracy: variable(0.8999999761581421)
# Now at  55
# loss: variable(0.21803617477416992)
# accuracy: variable(0.8999999761581421)
# Now at  56
# loss: variable(0.3590640127658844)
# accuracy: variable(0.8500000238418579)
# Now at  57
# loss: variable(0.2583284378051758)
# accuracy: variable(0.8999999761581421)
# Now at  58
# loss: variable(0.28149542212486267)
# accuracy: variable(0.8999999761581421)
# Now at  59
# loss: variable(0.34035369753837585)
# accuracy: variable(0.8500000238418579)
# Now at  60
# loss: variable(0.46278324723243713)
# accuracy: variable(0.800000011920929)
# Now at  61
# loss: variable(0.3232797682285309)
# accuracy: variable(0.8500000238418579)
# Now at  62
# loss: variable(0.3760935366153717)
# accuracy: variable(0.8500000238418579)
# Now at  63
# loss: variable(0.32654574513435364)
# accuracy: variable(0.8999999761581421)
# Now at  64
# loss: variable(0.29951560497283936)
# accuracy: variable(0.8999999761581421)
# Now at  65
# loss: variable(0.43171077966690063)
# accuracy: variable(0.8500000238418579)
# Now at  66
# loss: variable(0.3366667628288269)
# accuracy: variable(0.8999999761581421)
# Now at  67
# loss: variable(0.38645267486572266)
# accuracy: variable(0.8999999761581421)
# Now at  68
# loss: variable(0.6214640140533447)
# accuracy: variable(0.6000000238418579)
# Now at  69
# loss: variable(0.3982298970222473)
# accuracy: variable(0.800000011920929)
# Now at  70
# loss: variable(0.20940911769866943)
# accuracy: variable(0.949999988079071)
# Now at  71
# loss: variable(0.34896084666252136)
# accuracy: variable(0.8999999761581421)
# Now at  72
# loss: variable(0.24123592674732208)
# accuracy: variable(0.949999988079071)
# Now at  73
# loss: variable(0.3472707271575928)
# accuracy: variable(0.8500000238418579)
# Now at  74
# loss: variable(0.2558279037475586)
# accuracy: variable(0.8999999761581421)
# Now at  75
# loss: variable(0.4537312090396881)
# accuracy: variable(0.800000011920929)
# Now at  76
# loss: variable(0.24373479187488556)
# accuracy: variable(0.949999988079071)
# Now at  77
# loss: variable(0.29461511969566345)
# accuracy: variable(0.8999999761581421)
# Now at  78
# loss: variable(0.6529049277305603)
# accuracy: variable(0.6000000238418579)
# Now at  79
# loss: variable(0.3308332562446594)
# accuracy: variable(0.8999999761581421)
# Now at  80
# loss: variable(0.22667630016803741)
# accuracy: variable(0.8999999761581421)
# Now at  81
# loss: variable(0.23949050903320312)
# accuracy: variable(0.8999999761581421)
# Now at  82
# loss: variable(0.33202481269836426)
# accuracy: variable(0.8999999761581421)
# Now at  83
# loss: variable(0.24732916057109833)
# accuracy: variable(0.8999999761581421)
# Now at  84
# loss: variable(0.24210798740386963)
# accuracy: variable(0.949999988079071)
# Now at  85
# loss: variable(0.4863646924495697)
# accuracy: variable(0.800000011920929)
# Now at  86
# loss: variable(0.29172709584236145)
# accuracy: variable(0.8500000238418579)
# Now at  87
# loss: variable(0.2697159945964813)
# accuracy: variable(0.8999999761581421)
# Now at  88
# loss: variable(0.38356050848960876)
# accuracy: variable(0.8500000238418579)
# Now at  89
# loss: variable(0.26604557037353516)
# accuracy: variable(0.8999999761581421)
# Now at  90
# loss: variable(0.3892019987106323)
# accuracy: variable(0.8500000238418579)
# Now at  91
# loss: variable(0.3052564561367035)
# accuracy: variable(0.8999999761581421)
# Now at  92
# loss: variable(0.32408925890922546)
# accuracy: variable(0.8999999761581421)
# Now at  93
# loss: variable(0.2982644736766815)
# accuracy: variable(0.8999999761581421)
# Now at  94
# loss: variable(0.34080585837364197)
# accuracy: variable(0.8999999761581421)
# Now at  95
# loss: variable(0.27739670872688293)
# accuracy: variable(0.8999999761581421)
# Now at  96
# loss: variable(0.2376144975423813)
# accuracy: variable(0.949999988079071)
# Now at  97
# loss: variable(0.36923328042030334)
# accuracy: variable(0.8999999761581421)
# Now at  98
# loss: variable(0.25478556752204895)
# accuracy: variable(0.8999999761581421)
# Now at  99
# loss: variable(0.3055568039417267)
# accuracy: variable(0.8999999761581421)
# Now at  100
# loss: variable(0.29204392433166504)
# accuracy: variable(0.8999999761581421)
# Now at  101
# loss: variable(0.1416991651058197)
# accuracy: variable(1.0)
# Now at  102
# loss: variable(0.251796692609787)
# accuracy: variable(0.8999999761581421)
# Now at  103
# loss: variable(0.1568915694952011)
# accuracy: variable(0.949999988079071)
# Now at  104
# loss: variable(0.364423006772995)
# accuracy: variable(0.8500000238418579)
# Now at  105
# loss: variable(0.31317803263664246)
# accuracy: variable(0.8999999761581421)
# Now at  106
# loss: variable(0.2319236546754837)
# accuracy: variable(0.949999988079071)
# Now at  107
# loss: variable(0.3945241868495941)
# accuracy: variable(0.8999999761581421)
# Now at  108
# loss: variable(0.3762015700340271)
# accuracy: variable(0.8500000238418579)
# Now at  109
# loss: variable(0.30279597640037537)
# accuracy: variable(0.8999999761581421)
# Now at  110
# loss: variable(0.2957053780555725)
# accuracy: variable(0.8999999761581421)
# Now at  111
# loss: variable(0.29826951026916504)
# accuracy: variable(0.8500000238418579)
# Now at  112
# loss: variable(0.3135785460472107)
# accuracy: variable(0.8999999761581421)
# Now at  113
# loss: variable(0.2704583406448364)
# accuracy: variable(0.8500000238418579)
# Now at  114
# loss: variable(0.2437303513288498)
# accuracy: variable(0.8999999761581421)
# Now at  115
# loss: variable(0.3202367424964905)
# accuracy: variable(0.8999999761581421)
# Now at  116
# loss: variable(0.20989148318767548)
# accuracy: variable(0.949999988079071)
# Now at  117
# loss: variable(0.22780144214630127)
# accuracy: variable(0.949999988079071)
# Now at  118
# loss: variable(0.5088834762573242)
# accuracy: variable(0.800000011920929)
# Now at  119
# loss: variable(0.3746795952320099)
# accuracy: variable(0.8500000238418579)
# Now at  120
# loss: variable(0.3192887008190155)
# accuracy: variable(0.8999999761581421)
# Now at  121
# loss: variable(0.32090285420417786)
# accuracy: variable(0.8999999761581421)
# Now at  122
# loss: variable(0.1981663554906845)
# accuracy: variable(0.949999988079071)
# Now at  123
# loss: variable(0.3429144620895386)
# accuracy: variable(0.8999999761581421)
# Now at  124
# loss: variable(0.2612788677215576)
# accuracy: variable(0.8999999761581421)
# Now at  125
# loss: variable(0.30925053358078003)
# accuracy: variable(0.8999999761581421)
# Now at  126
# loss: variable(0.38001394271850586)
# accuracy: variable(0.8500000238418579)
# Now at  127
# loss: variable(0.4234284460544586)
# accuracy: variable(0.800000011920929)
# Now at  128
# loss: variable(0.21763573586940765)
# accuracy: variable(0.949999988079071)
# Now at  129
# loss: variable(0.3268091380596161)
# accuracy: variable(0.8999999761581421)
# Now at  130
# loss: variable(0.4059002995491028)
# accuracy: variable(0.8500000238418579)
# Now at  131
# loss: variable(0.2448865920305252)
# accuracy: variable(0.8999999761581421)
# Now at  132
# loss: variable(0.37133368849754333)
# accuracy: variable(0.8500000238418579)
# Now at  133
# loss: variable(0.21019402146339417)
# accuracy: variable(0.949999988079071)
# Now at  134
# loss: variable(0.3043435513973236)
# accuracy: variable(0.8999999761581421)
# Now at  135
# loss: variable(0.2501316964626312)
# accuracy: variable(0.8999999761581421)
# Now at  136
# loss: variable(0.28251132369041443)
# accuracy: variable(0.8999999761581421)
# Now at  137
# loss: variable(0.21783128380775452)
# accuracy: variable(0.949999988079071)
# Now at  138
# loss: variable(0.22060255706310272)
# accuracy: variable(0.949999988079071)
# Now at  139
# loss: variable(0.2928609251976013)
# accuracy: variable(0.8999999761581421)
# Now at  140
# loss: variable(0.3577005863189697)
# accuracy: variable(0.8500000238418579)
# Now at  141
# loss: variable(0.26361361145973206)
# accuracy: variable(0.8999999761581421)
# Now at  142
# loss: variable(0.27895307540893555)
# accuracy: variable(0.8999999761581421)
# Now at  143
# loss: variable(0.39449167251586914)
# accuracy: variable(0.8500000238418579)
# Now at  144
# loss: variable(0.31737664341926575)
# accuracy: variable(0.8999999761581421)
# Now at  145
# loss: variable(0.26711782813072205)
# accuracy: variable(0.8999999761581421)
# Now at  146
# loss: variable(0.2794385254383087)
# accuracy: variable(0.8999999761581421)
# Now at  147
# loss: variable(0.21695247292518616)
# accuracy: variable(0.949999988079071)
# Now at  148
# loss: variable(0.318651407957077)
# accuracy: variable(0.8999999761581421)
# Now at  149
# loss: variable(0.2061624377965927)
# accuracy: variable(0.8999999761581421)
# Now at  150
# loss: variable(0.2560856342315674)
# accuracy: variable(0.8999999761581421)
# Now at  151
# loss: variable(0.37233179807662964)
# accuracy: variable(0.8999999761581421)
# Now at  152
# loss: variable(0.2863284945487976)
# accuracy: variable(0.8999999761581421)
# Now at  153
# loss: variable(0.2803358733654022)
# accuracy: variable(0.8999999761581421)
# Now at  154
# loss: variable(0.2846836745738983)
# accuracy: variable(0.8999999761581421)
# Now at  155
# loss: variable(0.21877245604991913)
# accuracy: variable(0.949999988079071)
# Now at  156
# loss: variable(0.20413325726985931)
# accuracy: variable(0.949999988079071)
# Now at  157
# loss: variable(0.35719531774520874)
# accuracy: variable(0.8500000238418579)
# Now at  158
# loss: variable(0.3507431745529175)
# accuracy: variable(0.8500000238418579)
# Now at  159
# loss: variable(0.16651976108551025)
# accuracy: variable(0.949999988079071)
# Now at  160
# loss: variable(0.1627788245677948)
# accuracy: variable(0.949999988079071)
# Now at  161
# loss: variable(0.311072438955307)
# accuracy: variable(0.8999999761581421)
# Now at  162
# loss: variable(0.2318187803030014)
# accuracy: variable(0.949999988079071)
# Now at  163
# loss: variable(0.20859575271606445)
# accuracy: variable(0.949999988079071)
# Now at  164
# loss: variable(0.30391475558280945)
# accuracy: variable(0.8500000238418579)
# Now at  165
# loss: variable(0.36373305320739746)
# accuracy: variable(0.8500000238418579)
# Now at  166
# loss: variable(0.31279823184013367)
# accuracy: variable(0.8500000238418579)
# Now at  167
# loss: variable(0.21148681640625)
# accuracy: variable(0.949999988079071)
# Now at  168
# loss: variable(0.2691987454891205)
# accuracy: variable(0.8999999761581421)
# Now at  169
# loss: variable(0.2859254479408264)
# accuracy: variable(0.8500000238418579)
# Now at  170
# loss: variable(0.20238089561462402)
# accuracy: variable(0.949999988079071)
# Now at  171
# loss: variable(0.13451814651489258)
# accuracy: variable(1.0)
# Now at  172
# loss: variable(0.27107083797454834)
# accuracy: variable(0.8999999761581421)
# Now at  173
# loss: variable(0.2365684062242508)
# accuracy: variable(0.8999999761581421)
# Now at  174
# loss: variable(0.33726462721824646)
# accuracy: variable(0.8500000238418579)
# Now at  175
# loss: variable(0.23599444329738617)
# accuracy: variable(0.8500000238418579)
# Now at  176
# loss: variable(0.2574985921382904)
# accuracy: variable(0.8999999761581421)
# Now at  177
# loss: variable(0.23185411095619202)
# accuracy: variable(0.8999999761581421)
# Now at  178
# loss: variable(0.21143126487731934)
# accuracy: variable(0.8999999761581421)
# Now at  179
# loss: variable(0.3276679515838623)
# accuracy: variable(0.8500000238418579)
# Now at  180
# loss: variable(0.30516278743743896)
# accuracy: variable(0.8500000238418579)
# Now at  181
# loss: variable(0.3018127381801605)
# accuracy: variable(0.8500000238418579)
# Now at  182
# loss: variable(0.23958002030849457)
# accuracy: variable(0.8999999761581421)
# Now at  183
# loss: variable(0.319587767124176)
# accuracy: variable(0.8999999761581421)
# Now at  184
# loss: variable(0.213710218667984)
# accuracy: variable(0.949999988079071)
# Now at  185
# loss: variable(0.3353440761566162)
# accuracy: variable(0.8500000238418579)
# Now at  186
# loss: variable(0.1727844923734665)
# accuracy: variable(0.949999988079071)
# Now at  187
# loss: variable(0.24448256194591522)
# accuracy: variable(0.8999999761581421)
# Now at  188
# loss: variable(0.46899279952049255)
# accuracy: variable(0.8500000238418579)
# Now at  189
# loss: variable(0.22360239923000336)
# accuracy: variable(0.8999999761581421)
# Now at  190
# loss: variable(0.27775558829307556)
# accuracy: variable(0.8500000238418579)
# Now at  191
# loss: variable(0.22657309472560883)
# accuracy: variable(0.8999999761581421)
# Now at  192
# loss: variable(0.1795574128627777)
# accuracy: variable(0.949999988079071)
# Now at  193
# loss: variable(0.2098410576581955)
# accuracy: variable(0.8999999761581421)
# Now at  194
# loss: variable(0.27910423278808594)
# accuracy: variable(0.8500000238418579)
# Now at  195
# loss: variable(0.18924547731876373)
# accuracy: variable(0.8999999761581421)
# Now at  196
# loss: variable(0.39539167284965515)
# accuracy: variable(0.8500000238418579)
# Now at  197
# loss: variable(0.13325805962085724)
# accuracy: variable(1.0)
# Now at  198
# loss: variable(0.37340837717056274)
# accuracy: variable(0.8500000238418579)
# Now at  199
# loss: variable(0.3113277852535248)
# accuracy: variable(0.8500000238418579)
# Now at  200
# loss: variable(0.20506702363491058)
# accuracy: variable(0.949999988079071)

# %% [markdown]
# ### 作成モデルを格子点に適用して可視化
#
# 作成したデータ点-クラスラベルを学習したモデルを用いて
#
# 各格子点をどのようにクラス分けするか見る
#
# これによって分類境界を見ることができる

# %%
y = model(sample_mesh)

predict_label = F.argmax(y, axis=1).data
type(predict_label)

#テスト用データの表示
cm = generate_cmap(['#000000', '#FFFFFF'])
plt.scatter(sample_mesh[:,0], sample_mesh[:,1], c=predict_label, cmap=cm)

cm = generate_cmap(['#EE5050', '#9090FF'])
plt.scatter(sample_train[:,0], sample_train[:,1], c=sample_train_t, cmap=cm)

#テスト用データの表示
#plt.scatter(sample_test[:,0], sample_test[:,1], c=sample_test_t, cmap=cm_test)
# Out:
# numpy.ndarray

# %% [markdown]
# 黒 = 学習用データクラス0
#
# 白 = 学習用データクラス1
#
# （表示している場合）緑と桃はテスト用データ…accuracyとlossの途中経過レポートに使われている
#
# 赤 = 学習したモデルが判定したクラス0
#
# 青 = 学習したモデルが判定したクラス1

# %% [markdown]
# ### 知見など
#
# 今回の用にサンプル数が少ないと、バッチサイズを大きくしすぎるとコーナーケースのlossが潰れる？（図右端のクラス1（青）など）
#
# やはり学習率は重要っぽい
#
# 他中間ノード数などで調節可能
#
# 学習率=0.01～0.005で、学習数（＝データ数×エポック数）が多くないと全然分類できない模様？
#
# 80サンプルで200epoch
#
# 200サンプルで40epochぐらいで見た目よい結果
#
#
# 活性化関数はtanhがよいのかも？
#
# https://qiita.com/miyamotok0105/items/3435930cc04650bce54d
